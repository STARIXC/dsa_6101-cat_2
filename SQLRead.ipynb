# %% [markdown]
# Read data from mysql we need some specific import for instance sqlalchemy

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:test@localhost/social')

# %%
sqldf=pd.read_sql('select * from users',con=engine)

# %%
sqldf
# Out:
#    id username               email  \
# 0   1     test      test@gmail.com
# 1   2    test2     test2@gmail.com
# 2   3    test3     test3@gmail.com
# 3   4   tester    tester@gmail.com
# 4   5  console  tester@console.com
# 5   6  starixc   starixc@gmail.com
# 6   7    Evans      evans@test.com
# 7   8    Chris      chtis@test.com
# 8   9
# 9  10   test19    test19@gmail.com
#
#                                             password       name  \
# 0  $2a$10$IxFYHW3Byk9xLW..4NN7gOGua6NAdDI14erka0p...  Mwikali M
# 1  $2a$10$.caoC36BDRTYU60x4jogAenOFR0fJWdSi.BfP4L...      Test2
# 2  $2a$10$mHybinYMgDNCZX3jKZlCtudRlEkK4xRG27ApyRw...   Sane Roe
# 3  $2a$10$ofSA8jwvGheKXR8wiMjtnOrAKeEPAbb5XGc9g2W...     Tester
# 4  $2a$10$ndO1rgKTFz9LUZGfONinOuPVS58PAYkbnn7xKSd...    Console
# 5  $2a$10$pDbQ47XdHWaVzZY4xoTA2e3bdH5X/MoYcJtonUt...    Account
# 6  $2a$10$2hrUr3.2kMMRb9N7K2tCwO1aeOLXT54NJsMn2Xt...      Evans
# 7  $2a$10$S.wyp05BDjpnLbhcbk43qOv8XH4L3usx6NBb2Um...      Chris
# ...
